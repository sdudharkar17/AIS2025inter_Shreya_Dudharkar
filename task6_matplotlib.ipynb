# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv("/content/sharma-kohli.csv")
data.head(50)
plt.plot(data['index'],data['V Kohli'], label='V Kohli')
plt.plot(data['index'],data['RG Sharma'], label='RG Sharma')
plt.title('Rohit Sharma Vs Virat Kohli')
plt.xlabel('year')
plt.ylabel('score')
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv("/content/sharma-kohli.csv")
data.head(50)
plt.bar(data['index'],data['V Kohli'], label='V Kohli')
plt.bar(data['index'],data['RG Sharma'], label='RG Sharma')
plt.title('Rohit Sharma Vs Virat Kohli')
plt.xlabel('year')
plt.ylabel('score')
plt.grid()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data=pd.read_csv("/content/sharma-kohli.csv")
data.head(50)
plt.scatter(data['index'],data['V Kohli'], label='V Kohli')
plt.scatter(data['index'],data['RG Sharma'], label='RG Sharma')
plt.title('Rohit Sharma Vs Virat Kohli')
plt.xlabel('year')
plt.ylabel('score')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("/content/batter.csv")
data
data.head(50)
plt.plot(data['batter'],data['avg'],color='yellow')
plt.plot(data['batter'],data['strike_rate'],color='green')
# plt.title('avg Vs strike_rate')
# plt.xlabel('batter')
#plt.ylabel('score')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("/content/batter.csv")
data
data.head(50)
plt.bar(data['batter'],data['avg'],color='yellow')
plt.bar(data['batter'],data['strike_rate'],color='green')
# plt.title('avg Vs strike_rate')
# plt.xlabel('batter')
#plt.ylabel('score')
# Out:
# <BarContainer object of 605 artists>

# %%
import numpy as npc
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("/content/batter.csv")
data
data.head(50)
plt.hist(data['avg'], bins=20, color='yellow', alpha=0.7, label='avg')
plt.hist(data['strike_rate'], bins=20, color='green', alpha=0.7, label='strike_rate')
plt.title('Distribution of Average and Strike Rate')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
import numpy as npc
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("/content/batter.csv")
data
data.head(50)
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(data['avg'])
# plt.title('avg')
# plt.xlabel('average')
#plt.ylabel('freguency')

plt.subplot(1,2,1)
plt.hist(data['strike_rate'])
# plt.title('strike_rate')
# plt.xlabel('strike_rate')
#plt.ylabel('freguency')


plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=np.random.normal(loc=50,scale=10,size=1000)
sns.histplot(data,bins=20,kde=True,color='green')
# plt.title('histogram')
# plt.xlabel('value')
# plt.ylabel('frequency')
#plt.show()
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips=sns.load_dataset('tips')
sns.boxplot(x='day',y='total_bill',data=tips)
# plt.title('boxplot')
# plt.xlabel('day')
# plt.ylabel('total_bill')
#plt.show()
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex")
plt.title("scatterplot")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(tips,hue="sex")
plt.suptitle("pairplot",y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = tips.corr(numeric_only=True) # Calculate the correlation matrix
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("correlation heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
x=np.linspace(0,10,100)
y=np.sin(x)
plt.figure(figsize=(8,4))
plt.plot(x,y,color='purple',linestyle='--',marker='o')
plt.title('sine wave')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
categories=['A','B','C','D']
values=[23,45,12,36]
plt.bar(categories,values,color='orange')
plt.title('bar chart')
plt.xlabel('categories')
plt.ylabel('values')
plt.show()
